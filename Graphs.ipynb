# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-10, 10, 20)

plt.plot(x, (3*(x**2)) + (20*x), label='i')
#plt.plot(x, (6*x) + 20, label='tangent')
plt.hlines(-100/3, -10, 10, label = 'tangent')

#plt.plot(x, (x**3) - (3*(x**2)) + (5*x) + 8, label='ii')
#plt.plot(x, (3*(x**2)) - (6*x) + 5, label='tangent')

plt.xlabel('x label')
plt.ylabel('y label')

#plt.hlines((99+(8*np.sqrt(6)))/9, -10, 10, label = 'tangent')

#plt.hlines((99-(8*np.sqrt(6)))/9, -10, 10, label = 'tangent')


#plt.scatter((-10/3),(-100/3),color='#ff0000')

#plt.scatter((1+(np.sqrt(6)/3)),((99+(8*np.sqrt(6)))/9),color='#008000')

#plt.scatter((1-(np.sqrt(6)/3)),((99-(8*np.sqrt(6)))/9),color='#ff0000')

plt.title("i")

plt.legend()

plt.show()
